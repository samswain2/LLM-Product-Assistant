# %%
# ----- Import Libraries -----
import openai
from dotenv import load_dotenv
import os
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# ----- User Settings -----
input_file_path = '../06_Data/Capstone_Data/Classified_VPC_Links.csv'
output_file_path = '../06_Data/Capstone_Data/Documentation_QA_Pairs.csv'
openai_api_key_env_var = "OPENAI_KEY"
max_tokens = 1000

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import os

def fetch_and_clean_webpage(url, cache_file):
    # Check if the content is already in the cache
    if url in cache_file:
        return cache_file[url]

    try:
        response = requests.get(url)
        if response.status_code != 200:
            return "Failed to retrieve the webpage"
        soup = BeautifulSoup(response.text, 'html.parser')
        main_content = soup.find('main') or soup.body
        for script in main_content(["script", "style"]):
            script.decompose()
        cleaned_text = main_content.get_text(separator='\n', strip=True)
        cache_file[url] = cleaned_text  # Save to cache
        return cleaned_text
    except Exception as e:
        return f"Error fetching page: {e}"

def process_links(csv_file, limit=None, cache_filename='content_cache.json'):
    links_df = pd.read_csv(csv_file)
    text_links = links_df[links_df['Type'] == 'text-based']['LINK']

    # Load cache file if it exists, otherwise create an empty cache
    if os.path.exists(cache_filename):
        with open(cache_filename, 'r') as file:
            cache_file = json.load(file)
    else:
        cache_file = {}

    results = {}
    for i, link in enumerate(text_links):
        if limit and i >= limit:
            break
        content = fetch_and_clean_webpage(link, cache_file)
        results[link] = content
        print(f"Processed {i+1}/{len(text_links)}: {link}")

    # Save the updated cache file
    with open(cache_filename, 'w') as file:
        json.dump(cache_file, file)

    return results

# Example usage
processed_contents = process_links(input_file_path)
# Out:
# Processed 1/392: https://docs.aws.amazon.com/cli/latest/reference/vpc-lattice/
# Processed 2/392: https://docs.aws.amazon.com/vpc/latest/userguide/how-it-works.html
# Processed 3/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-getting-started.html
# Processed 4/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-ip-addressing.html
# Processed 5/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-cidr-blocks.html
# Processed 6/392: https://docs.aws.amazon.com/vpc/latest/userguide/subnet-sizing.html
# Processed 7/392: https://docs.aws.amazon.com/vpc/latest/userguide/managed-prefix-lists.html
# Processed 8/392: https://docs.aws.amazon.com/vpc/latest/userguide/working-with-managed-prefix-lists.html
# Processed 9/392: https://docs.aws.amazon.com/vpc/latest/userguide/working-with-aws-managed-prefix-lists.html
# Processed 10/392: https://docs.aws.amazon.com/vpc/latest/userguide/sharing-managed-prefix-lists.html
# Processed 11/392: https://docs.aws.amazon.com/vpc/latest/userguide/managed-prefix-lists-referencing.html
# Processed 12/392: https://docs.aws.amazon.com/vpc/latest/userguide/aws-ip-ranges.html
# Processed 13/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-migrate-ipv6.html
# Processed 14/392: https://docs.aws.amazon.com/vpc/latest/userguide/aws-ipv6-support.html
# Processed 15/392: https://docs.aws.amazon.com/vpc/latest/userguide/configure-your-vpc.html
# Processed 16/392: https://docs.aws.amazon.com/vpc/latest/userguide/default-vpc.html
# Processed 17/392: https://docs.aws.amazon.com/vpc/latest/userguide/create-vpc.html
# Processed 18/392: https://docs.aws.amazon.com/vpc/latest/userguide/modify-vpcs.html
# Processed 19/392: https://docs.aws.amazon.com/vpc/latest/userguide/VPC_DHCP_Options.html
# Processed 20/392: https://docs.aws.amazon.com/vpc/latest/userguide/DHCPOptionSetConcepts.html
# Processed 21/392: https://docs.aws.amazon.com/vpc/latest/userguide/DHCPOptionSet.html
# Processed 22/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-dns.html
# Processed 23/392: https://docs.aws.amazon.com/vpc/latest/userguide/network-address-usage.html
# Processed 24/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-sharing.html
# Processed 25/392: https://docs.aws.amazon.com/vpc/latest/userguide/example-vpc-share.html
# Processed 26/392: https://docs.aws.amazon.com/vpc/latest/userguide/Extend_VPCs.html
# Processed 27/392: https://docs.aws.amazon.com/vpc/latest/userguide/delete-vpc.html
# Processed 28/392: https://docs.aws.amazon.com/vpc/latest/userguide/configure-subnets.html
# Processed 29/392: https://docs.aws.amazon.com/vpc/latest/userguide/create-subnets.html
# Processed 30/392: https://docs.aws.amazon.com/vpc/latest/userguide/modify-subnets.html
# Processed 31/392: https://docs.aws.amazon.com/vpc/latest/userguide/subnet-cidr-reservation.html
# Processed 32/392: https://docs.aws.amazon.com/vpc/latest/userguide/VPC_Route_Tables.html
# Processed 33/392: https://docs.aws.amazon.com/vpc/latest/userguide/route-table-options.html
# Processed 34/392: https://docs.aws.amazon.com/vpc/latest/userguide/WorkWithRouteTables.html
# Processed 35/392: https://docs.aws.amazon.com/vpc/latest/userguide/middlebox-routing-console.html
# Processed 36/392: https://docs.aws.amazon.com/vpc/latest/userguide/working-with-routing-console.html
# Processed 37/392: https://docs.aws.amazon.com/vpc/latest/userguide/middlebox-routing-examples.html
# Processed 38/392: https://docs.aws.amazon.com/vpc/latest/userguide/internet-gateway-subnet.html
# Processed 39/392: https://docs.aws.amazon.com/vpc/latest/userguide/gwlb-route.html
# Processed 40/392: https://docs.aws.amazon.com/vpc/latest/userguide/intra-vpc-route.html
# Processed 41/392: https://docs.aws.amazon.com/vpc/latest/userguide/subnet-deleting.html
# Processed 42/392: https://docs.aws.amazon.com/vpc/latest/userguide/extend-intro.html
# Processed 43/392: https://docs.aws.amazon.com/vpc/latest/userguide/VPC_Internet_Gateway.html
# Processed 44/392: https://docs.aws.amazon.com/vpc/latest/userguide/egress-only-internet-gateway.html
# Processed 45/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-nat.html
# Processed 46/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-nat-gateway.html
# Processed 47/392: https://docs.aws.amazon.com/vpc/latest/userguide/nat-gateway-scenarios.html
# Processed 48/392: https://docs.aws.amazon.com/vpc/latest/userguide/nat-gateway-nat64-dns64.html
# Processed 49/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-nat-gateway-cloudwatch.html
# Processed 50/392: https://docs.aws.amazon.com/vpc/latest/userguide/nat-gateway-troubleshooting.html
# Processed 51/392: https://docs.aws.amazon.com/vpc/latest/userguide/VPC_NAT_Instance.html
# Processed 52/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-eips.html
# Processed 53/392: https://docs.aws.amazon.com/vpc/latest/userguide/extend-tgw.html
# Processed 54/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpn-connections.html
# Processed 55/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-peering.html
# Processed 56/392: https://docs.aws.amazon.com/vpc/latest/userguide/monitoring.html
# Processed 57/392: https://docs.aws.amazon.com/vpc/latest/userguide/flow-logs.html
# Processed 58/392: https://docs.aws.amazon.com/vpc/latest/userguide/flow-logs-records-examples.html
# Processed 59/392: https://docs.aws.amazon.com/vpc/latest/userguide/working-with-flow-logs.html
# Processed 60/392: https://docs.aws.amazon.com/vpc/latest/userguide/flow-logs-cwl.html
# Processed 61/392: https://docs.aws.amazon.com/vpc/latest/userguide/flow-logs-s3.html
# Processed 62/392: https://docs.aws.amazon.com/vpc/latest/userguide/flow-logs-firehose.html
# Processed 63/392: https://docs.aws.amazon.com/vpc/latest/userguide/flow-logs-athena.html
# Processed 64/392: https://docs.aws.amazon.com/vpc/latest/userguide/flow-logs-troubleshooting.html
# Processed 65/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-cloudwatch.html
# Processed 66/392: https://docs.aws.amazon.com/vpc/latest/userguide/security.html
# Processed 67/392: https://docs.aws.amazon.com/vpc/latest/userguide/data-protection.html
# Processed 68/392: https://docs.aws.amazon.com/vpc/latest/userguide/VPC_Security.html
# Processed 69/392: https://docs.aws.amazon.com/vpc/latest/userguide/security-iam.html
# Processed 70/392: https://docs.aws.amazon.com/vpc/latest/userguide/security_iam_service-with-iam.html
# Processed 71/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-policy-examples.html
# Processed 72/392: https://docs.aws.amazon.com/vpc/latest/userguide/security_iam_troubleshoot.html
# Processed 73/392: https://docs.aws.amazon.com/vpc/latest/userguide/security-iam-awsmanpol.html
# Processed 74/392: https://docs.aws.amazon.com/vpc/latest/userguide/infrastructure-security.html
# Processed 75/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-security-groups.html
# Processed 76/392: https://docs.aws.amazon.com/vpc/latest/userguide/security-groups.html
# Processed 77/392: https://docs.aws.amazon.com/vpc/latest/userguide/security-group-rules.html
# Processed 78/392: https://docs.aws.amazon.com/vpc/latest/userguide/default-security-group.html
# Processed 79/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-network-acls.html
# Processed 80/392: https://docs.aws.amazon.com/vpc/latest/userguide/disaster-recovery-resiliency.html
# Processed 81/392: https://docs.aws.amazon.com/vpc/latest/userguide/VPC-compliance.html
# Processed 82/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-security-best-practices.html
# Processed 83/392: https://docs.aws.amazon.com/vpc/latest/userguide/related-services.html
# Processed 84/392: https://docs.aws.amazon.com/vpc/latest/userguide/endpoint-services-overview.html
# Processed 85/392: https://docs.aws.amazon.com/vpc/latest/userguide/network-firewall.html
# Processed 86/392: https://docs.aws.amazon.com/vpc/latest/userguide/resolver-dns-firewall.html
# Processed 87/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-examples-intro.html
# Processed 88/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-example-dev-test.html
# Processed 89/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-example-web-database-servers.html
# Processed 90/392: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-example-private-subnets-nat.html
# Processed 91/392: https://docs.aws.amazon.com/vpc/latest/userguide/amazon-vpc-limits.html
# Processed 92/392: https://docs.aws.amazon.com/vpc/latest/userguide/WhatsNew.html
# Processed 93/392: https://docs.aws.amazon.com/vpc/latest/peering/what-is-vpc-peering.html
# Processed 94/392: https://docs.aws.amazon.com/vpc/latest/peering/vpc-peering-basics.html
# Processed 95/392: https://docs.aws.amazon.com/vpc/latest/peering/working-with-vpc-peering.html
# Processed 96/392: https://docs.aws.amazon.com/vpc/latest/peering/create-vpc-peering-connection.html
# Processed 97/392: https://docs.aws.amazon.com/vpc/latest/peering/accept-vpc-peering-connection.html
# Processed 98/392: https://docs.aws.amazon.com/vpc/latest/peering/reject-vpc-peering-connection.html
# Processed 99/392: https://docs.aws.amazon.com/vpc/latest/peering/describe-vpc-peering-connections.html
# Processed 100/392: https://docs.aws.amazon.com/vpc/latest/peering/vpc-peering-routing.html
# Processed 101/392: https://docs.aws.amazon.com/vpc/latest/peering/vpc-peering-security-groups.html
# Processed 102/392: https://docs.aws.amazon.com/vpc/latest/peering/modify-peering-connections.html
# Processed 103/392: https://docs.aws.amazon.com/vpc/latest/peering/delete-vpc-peering-connection.html
# Processed 104/392: https://docs.aws.amazon.com/vpc/latest/peering/troubleshoot-vpc-peering-connections.html
# Processed 105/392: https://docs.aws.amazon.com/vpc/latest/peering/peering-configurations.html
# Processed 106/392: https://docs.aws.amazon.com/vpc/latest/peering/peering-configurations-full-access.html
# Processed 107/392: https://docs.aws.amazon.com/vpc/latest/peering/peering-configurations-partial-access.html
# Processed 108/392: https://docs.aws.amazon.com/vpc/latest/peering/peering-scenarios.html
# Processed 109/392: https://docs.aws.amazon.com/vpc/latest/peering/security-iam.html
# Processed 110/392: https://docs.aws.amazon.com/vpc/latest/peering/vpc-peering-connection-quotas.html
# Processed 111/392: https://docs.aws.amazon.com/vpc/latest/peering/doc-history.html
# Processed 112/392: https://docs.aws.amazon.com/vpc/latest/mirroring/what-is-traffic-mirroring.html
# Processed 113/392: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-how-it-works.html
# Processed 114/392: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-targets.html
# Processed 115/392: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-sessions.html
# Processed 116/392: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-connection.html
# Processed 117/392: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-packet-formats.html
# Processed 118/392: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-getting-started.html
# Processed 119/392: https://docs.aws.amazon.com/vpc/latest/mirroring/Traffic_Mirroring_Scenarios.html
# Processed 120/392: https://docs.aws.amazon.com/vpc/latest/mirroring/tm-example-inbound-tcp.html
# Processed 121/392: https://docs.aws.amazon.com/vpc/latest/mirroring/tm-example-inbound-tcp-udp.html
# Processed 122/392: https://docs.aws.amazon.com/vpc/latest/mirroring/tm-example-non-vpc.html
# Processed 123/392: https://docs.aws.amazon.com/vpc/latest/mirroring/tm-example-glb-endpoints.html
# Processed 124/392: https://docs.aws.amazon.com/vpc/latest/mirroring/working-with-traffic-mirroring.html
# Processed 125/392: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-target.html
# Processed 126/392: https://docs.aws.amazon.com/vpc/latest/mirroring/cross-account-traffic-mirroring-targets.html
# Processed 127/392: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-filter.html
# Processed 128/392: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-session.html
# Processed 129/392: https://docs.aws.amazon.com/vpc/latest/mirroring/tm-example-open-source.html
# Processed 130/392: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirror-cloudwatch.html
# Processed 131/392: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-limits.html
# Processed 132/392: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-security.html
# Processed 133/392: https://docs.aws.amazon.com/vpc/latest/mirroring/doc-history.html
# Processed 134/392: https://docs.aws.amazon.com/vpc/latest/privatelink/what-is-privatelink.html
# Processed 135/392: https://docs.aws.amazon.com/vpc/latest/privatelink/concepts.html
# Processed 136/392: https://docs.aws.amazon.com/vpc/latest/privatelink/getting-started.html
# Processed 137/392: https://docs.aws.amazon.com/vpc/latest/privatelink/privatelink-access-aws-services.html
# Processed 138/392: https://docs.aws.amazon.com/vpc/latest/privatelink/aws-services-privatelink-support.html
# Processed 139/392: https://docs.aws.amazon.com/vpc/latest/privatelink/create-interface-endpoint.html
# Processed 140/392: https://docs.aws.amazon.com/vpc/latest/privatelink/interface-endpoints.html
# Processed 141/392: https://docs.aws.amazon.com/vpc/latest/privatelink/manage-notifications-endpoint.html
# Processed 142/392: https://docs.aws.amazon.com/vpc/latest/privatelink/delete-interface-endpoint.html
# Processed 143/392: https://docs.aws.amazon.com/vpc/latest/privatelink/gateway-endpoints.html
# Processed 144/392: https://docs.aws.amazon.com/vpc/latest/privatelink/vpc-endpoints-s3.html
# Processed 145/392: https://docs.aws.amazon.com/vpc/latest/privatelink/vpc-endpoints-ddb.html
# Processed 146/392: https://docs.aws.amazon.com/vpc/latest/privatelink/privatelink-access-saas.html
# Processed 147/392: https://docs.aws.amazon.com/vpc/latest/privatelink/vpce-gateway-load-balancer.html
# Processed 148/392: https://docs.aws.amazon.com/vpc/latest/privatelink/create-gateway-load-balancer-endpoint-service.html
# Processed 149/392: https://docs.aws.amazon.com/vpc/latest/privatelink/gateway-load-balancer-endpoints.html
# Processed 150/392: https://docs.aws.amazon.com/vpc/latest/privatelink/privatelink-share-your-services.html
# Processed 151/392: https://docs.aws.amazon.com/vpc/latest/privatelink/create-endpoint-service.html
# Processed 152/392: https://docs.aws.amazon.com/vpc/latest/privatelink/configure-endpoint-service.html
# Processed 153/392: https://docs.aws.amazon.com/vpc/latest/privatelink/manage-dns-names.html
# Processed 154/392: https://docs.aws.amazon.com/vpc/latest/privatelink/create-notification-endpoint-service.html
# Processed 155/392: https://docs.aws.amazon.com/vpc/latest/privatelink/delete-endpoint-service.html
# Processed 156/392: https://docs.aws.amazon.com/vpc/latest/privatelink/vpc-endpoints-iam.html
# Processed 157/392: https://docs.aws.amazon.com/vpc/latest/privatelink/security_iam_service-with-iam.html
# Processed 158/392: https://docs.aws.amazon.com/vpc/latest/privatelink/security_iam_id-based-policy-examples.html
# Processed 159/392: https://docs.aws.amazon.com/vpc/latest/privatelink/vpc-endpoints-access.html
# Processed 160/392: https://docs.aws.amazon.com/vpc/latest/privatelink/privatelink-cloudwatch-metrics.html
# Processed 161/392: https://docs.aws.amazon.com/vpc/latest/privatelink/vpc-limits-endpoints.html
# Processed 162/392: https://docs.aws.amazon.com/vpc/latest/privatelink/doc-history.html
# Processed 163/392: https://docs.aws.amazon.com/vpc/latest/tgw/what-is-transit-gateway.html
# Processed 164/392: https://docs.aws.amazon.com/vpc/latest/tgw/how-transit-gateways-work.html
# Processed 165/392: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-getting-started.html
# Processed 166/392: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-best-design-practices.html
# Processed 167/392: https://docs.aws.amazon.com/vpc/latest/tgw/TGW_Scenarios.html
# Processed 168/392: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-centralized-router.html
# Processed 169/392: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-isolated.html
# Processed 170/392: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-isolated-shared.html
# Processed 171/392: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-peering-scenario.html
# Processed 172/392: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-nat-igw.html
# Processed 173/392: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-appliance-scenario.html
# Processed 174/392: https://docs.aws.amazon.com/vpc/latest/tgw/working-with-transit-gateways.html
# Processed 175/392: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-transit-gateways.html
# Processed 176/392: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-vpc-attachments.html
# Processed 177/392: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-vpn-attachments.html
# Processed 178/392: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-dcg-attachments.html
# Processed 179/392: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-peering.html
# Processed 180/392: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-connect.html
# Processed 181/392: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-route-tables.html
# Processed 182/392: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-prefix-lists.html
# Processed 183/392: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-policy-tables.html
# Processed 184/392: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-multicast-overview.html
# Processed 185/392: https://docs.aws.amazon.com/vpc/latest/tgw/how-multicast-works.html
# Processed 186/392: https://docs.aws.amazon.com/vpc/latest/tgw/working-with-multicast.html
# Processed 187/392: https://docs.aws.amazon.com/vpc/latest/tgw/manage-domain.html
# Processed 188/392: https://docs.aws.amazon.com/vpc/latest/tgw/manage-multicast-group.html
# Processed 189/392: https://docs.aws.amazon.com/vpc/latest/tgw/multicast-sharing.html
# Processed 190/392: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-share.html
# Processed 191/392: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-flow-logs.html
# Processed 192/392: https://docs.aws.amazon.com/vpc/latest/tgw/flow-logs-cwl.html
# Processed 193/392: https://docs.aws.amazon.com/vpc/latest/tgw/flow-logs-s3.html
# Processed 194/392: https://docs.aws.amazon.com/vpc/latest/tgw/flow-logs-kinesis.html
# Processed 195/392: https://docs.aws.amazon.com/vpc/latest/tgw/working-with-flow-logs.html
# Processed 196/392: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-monitoring.html
# Processed 197/392: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-cloudwatch-metrics.html
# Processed 198/392: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-cloudtrail-logs.html
# Processed 199/392: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-authentication-access-control.html
# Processed 200/392: https://docs.aws.amazon.com/vpc/latest/tgw/service-linked-roles.html
# Processed 201/392: https://docs.aws.amazon.com/vpc/latest/tgw/security-iam-awsmanpol.html
# Processed 202/392: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-nacls.html
# Processed 203/392: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-quotas.html
# Processed 204/392: https://docs.aws.amazon.com/vpc/latest/tgw/doc-history.html
# Processed 205/392: https://docs.aws.amazon.com/vpc/latest/ipam/what-it-is-ipam.html
# Processed 206/392: https://docs.aws.amazon.com/vpc/latest/ipam/how-it-works-ipam.html
# Processed 207/392: https://docs.aws.amazon.com/vpc/latest/ipam/access-ipam.html
# Processed 208/392: https://docs.aws.amazon.com/vpc/latest/ipam/choose-single-user-or-orgs-ipam.html
# Processed 209/392: https://docs.aws.amazon.com/vpc/latest/ipam/enable-integ-ipam.html
# Processed 210/392: https://docs.aws.amazon.com/vpc/latest/ipam/enable-integ-ipam-outside-org.html
# Processed 211/392: https://docs.aws.amazon.com/vpc/latest/ipam/enable-integ-ipam-outside-org-considerations.html
# Processed 212/392: https://docs.aws.amazon.com/vpc/latest/ipam/enable-integ-ipam-outside-org-process.html
# Processed 213/392: https://docs.aws.amazon.com/vpc/latest/ipam/enable-single-user-ipam.html
# Processed 214/392: https://docs.aws.amazon.com/vpc/latest/ipam/create-ipam.html
# Processed 215/392: https://docs.aws.amazon.com/vpc/latest/ipam/planning-ipam.html
# Processed 216/392: https://docs.aws.amazon.com/vpc/latest/ipam/planning-examples-ipam.html
# Processed 217/392: https://docs.aws.amazon.com/vpc/latest/ipam/intro-create-ipv4-pools.html
# Processed 218/392: https://docs.aws.amazon.com/vpc/latest/ipam/create-top-ipam.html
# Processed 219/392: https://docs.aws.amazon.com/vpc/latest/ipam/create-reg-ipam.html
# Processed 220/392: https://docs.aws.amazon.com/vpc/latest/ipam/create-dev-ipam.html
# Processed 221/392: https://docs.aws.amazon.com/vpc/latest/ipam/intro-create-ipv6-pools.html
# Processed 222/392: https://docs.aws.amazon.com/vpc/latest/ipam/create-ipv6-reg-pool.html
# Processed 223/392: https://docs.aws.amazon.com/vpc/latest/ipam/create-ipv6-dev-pool.html
# Processed 224/392: https://docs.aws.amazon.com/vpc/latest/ipam/allocate-cidrs-ipam.html
# Processed 225/392: https://docs.aws.amazon.com/vpc/latest/ipam/create-vpc-ipam.html
# Processed 226/392: https://docs.aws.amazon.com/vpc/latest/ipam/manually-allocate-ipam.html
# Processed 227/392: https://docs.aws.amazon.com/vpc/latest/ipam/managing-ip-space-ipam.html
# Processed 228/392: https://docs.aws.amazon.com/vpc/latest/ipam/scp-ipam.html
# Processed 229/392: https://docs.aws.amazon.com/vpc/latest/ipam/share-pool-ipam.html
# Processed 230/392: https://docs.aws.amazon.com/vpc/latest/ipam/prov-cidr-ipam.html
# Processed 231/392: https://docs.aws.amazon.com/vpc/latest/ipam/depro-pool-cidr-ipam.html
# Processed 232/392: https://docs.aws.amazon.com/vpc/latest/ipam/mod-pool-ipam.html
# Processed 233/392: https://docs.aws.amazon.com/vpc/latest/ipam/delete-pool-ipam.html
# Processed 234/392: https://docs.aws.amazon.com/vpc/latest/ipam/res-disc-work-with.html
# Processed 235/392: https://docs.aws.amazon.com/vpc/latest/ipam/res-disc-work-with-create.html
# Processed 236/392: https://docs.aws.amazon.com/vpc/latest/ipam/res-disc-work-with-view.html
# Processed 237/392: https://docs.aws.amazon.com/vpc/latest/ipam/res-disc-work-with-share.html
# Processed 238/392: https://docs.aws.amazon.com/vpc/latest/ipam/res-disc-work-with-associate.html
# Processed 239/392: https://docs.aws.amazon.com/vpc/latest/ipam/res-disc-work-with-disassociate.html
# Processed 240/392: https://docs.aws.amazon.com/vpc/latest/ipam/res-disc-work-with-delete.html
# Processed 241/392: https://docs.aws.amazon.com/vpc/latest/ipam/add-scope-ipam.html
# Processed 242/392: https://docs.aws.amazon.com/vpc/latest/ipam/move-resource-ipam.html
# Processed 243/392: https://docs.aws.amazon.com/vpc/latest/ipam/change-monitoring-state-ipam.html
# Processed 244/392: https://docs.aws.amazon.com/vpc/latest/ipam/delete-scope-ipam.html
# Processed 245/392: https://docs.aws.amazon.com/vpc/latest/ipam/release-alloc-ipam.html
# Processed 246/392: https://docs.aws.amazon.com/vpc/latest/ipam/delete-ipam.html
# Processed 247/392: https://docs.aws.amazon.com/vpc/latest/ipam/tracking-ip-addresses-ipam.html
# Processed 248/392: https://docs.aws.amazon.com/vpc/latest/ipam/monitor-cidr-usage-ipam.html
# Processed 249/392: https://docs.aws.amazon.com/vpc/latest/ipam/monitor-cidr-compliance-ipam.html
# Processed 250/392: https://docs.aws.amazon.com/vpc/latest/ipam/cloudwatch-ipam.html
# Processed 251/392: https://docs.aws.amazon.com/vpc/latest/ipam/cloudwatch-ipam-ip-address-usage.html
# Processed 252/392: https://docs.aws.amazon.com/vpc/latest/ipam/cloudwatch-ipam-res-util.html
# Processed 253/392: https://docs.aws.amazon.com/vpc/latest/ipam/view-history-cidr-ipam.html
# Processed 254/392: https://docs.aws.amazon.com/vpc/latest/ipam/view-public-ip-insights.html
# Processed 255/392: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-ipam.html
# Processed 256/392: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-get-started-console.html
# Processed 257/392: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-create-vpc-ipam.html
# Processed 258/392: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-historical-insights.html
# Processed 259/392: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-byoip-ipam.html
# Processed 260/392: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-byoip-ipam-console-intro.html
# Processed 261/392: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-byoip-ipam-console-ipv4.html
# Processed 262/392: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-byoip-ipam-console-ipv6.html
# Processed 263/392: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-byoip-ipam-cli-only-intro.html
# Processed 264/392: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-byoip-ipam-ipv4.html
# Processed 265/392: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-byoip-ipam-ipv6.html
# Processed 266/392: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-byoip-ipam-transfer-ipv4.html
# Processed 267/392: https://docs.aws.amazon.com/vpc/latest/ipam/iam-ipam.html
# Processed 268/392: https://docs.aws.amazon.com/vpc/latest/ipam/iam-ipam-slr.html
# Processed 269/392: https://docs.aws.amazon.com/vpc/latest/ipam/iam-ipam-managed-pol.html
# Processed 270/392: https://docs.aws.amazon.com/vpc/latest/ipam/iam-ipam-policy-examples.html
# Processed 271/392: https://docs.aws.amazon.com/vpc/latest/ipam/quotas-ipam.html
# Processed 272/392: https://docs.aws.amazon.com/vpc/latest/ipam/pricing-ipam.html
# Processed 273/392: https://docs.aws.amazon.com/vpc/latest/ipam/related-info.html
# Processed 274/392: https://docs.aws.amazon.com/vpc/latest/ipam/doc-history-ipam.html
# Processed 275/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/what-are-global-networks.html
# Processed 276/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/how-gnw-works.html
# Processed 277/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/gnw-getting-started.html
# Processed 278/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/gnw-scenarios.html
# Processed 279/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/working-with-gnws.html
# Processed 280/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-multi-account.html
# Processed 281/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-multi-account-troubleshooting.html
# Processed 282/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/global-networks.html
# Processed 283/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/tgw-registrations.html
# Processed 284/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/sites.html
# Processed 285/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/links.html
# Processed 286/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/devices.html
# Processed 287/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/device-connections.html
# Processed 288/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/cgw-association.html
# Processed 289/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/connect-peer-association.html
# Processed 290/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/tgw-visualize-networks.html
# Processed 291/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-monitoring-console.html
# Processed 292/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-visualize-tgw.html
# Processed 293/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/monitoring-overview.html
# Processed 294/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/monitoring-cloudwatch-metrics.html
# Processed 295/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/cw-metrics-on-premises.html
# Processed 296/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/viewing-metrics.html
# Processed 297/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/monitoring-events.html
# Processed 298/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/route-analyzer.html
# Processed 299/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/tgw-nm-multi.html
# Processed 300/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-security-iam.html
# Processed 301/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-service-linked-roles.html
# Processed 302/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/security-iam-awsmanpol.html
# Processed 303/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-custom-multi-role.html
# Processed 304/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/gnw-tagging.html
# Processed 305/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-logging-using-cloudtrail.html
# Processed 306/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-quotas.html
# Processed 307/392: https://docs.aws.amazon.com/network-manager/latest/tgwnm/doc-history.html
# Processed 308/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/what-is-cloudwan.html
# Processed 309/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-getting-started.html
# Processed 310/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/create-global-network.html
# Processed 311/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-core-network-policy.html
# Processed 312/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-create-attachment.html
# Processed 313/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-connect-attachment.html
# Processed 314/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-connect-peer-attachment.html
# Processed 315/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-tgw-attachment.html
# Processed 316/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-vpc-attachment.html
# Processed 317/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-vpn-attachment.html
# Processed 318/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-register-tgw.html
# Processed 319/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-sites.html
# Processed 320/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-devices.html
# Processed 321/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-working-with.html
# Processed 322/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-networks-working-with.html
# Processed 323/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-create-policy-version.html
# Processed 324/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-core-network-config.html
# Processed 325/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-segments.html
# Processed 326/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-network-actions-routes.html
# Processed 327/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-attachments.html
# Processed 328/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-change-sets.html
# Processed 329/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policies-json.html
# Processed 330/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-examples.html
# Processed 331/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-examples-one-segment-region.html
# Processed 332/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-examples-two-segments-regions.html
# Processed 333/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-examples-edge-consolidation.html
# Processed 334/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-examples-three-stage.html
# Processed 335/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-examples-distributed-wan.html
# Processed 336/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-examples-firewalls.html
# Processed 337/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-attachments-working-with.html
# Processed 338/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-peerings.html
# Processed 339/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-share-network.html
# Processed 340/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-shared.html
# Processed 341/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-attachments-share.html
# Processed 342/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-peerings-share.html
# Processed 343/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-tags.html
# Processed 344/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-sites-working-with.html
# Processed 345/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-devices-working.html
# Processed 346/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-visualize-networks.html
# Processed 347/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-visualize-networks-global.html
# Processed 348/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-visualize-networks-core.html
# Processed 349/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-visualize-tgw.html
# Processed 350/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-tgw-networks.html
# Processed 351/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-tgws-working-with.html
# Processed 352/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-security.html
# Processed 353/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/security-iam-awsmanpol.html
# Processed 354/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cwan-using-service-linked-roles.html
# Processed 355/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-events-metrics.html
# Processed 356/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-onboard-events.html
# Processed 357/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-cloudwatch-events.html
# Processed 358/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-cloudwatch-metrics.html
# Processed 359/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-quotas.html
# Processed 360/392: https://docs.aws.amazon.com/network-manager/latest/cloudwan/doc-history.html
# Processed 361/392: https://docs.aws.amazon.com/vpc/latest/reachability/what-is-reachability-analyzer.html
# Processed 362/392: https://docs.aws.amazon.com/vpc/latest/reachability/how-reachability-analyzer-works.html
# Processed 363/392: https://docs.aws.amazon.com/vpc/latest/reachability/getting-started.html
# Processed 364/392: https://docs.aws.amazon.com/vpc/latest/reachability/getting-started-cli.html
# Processed 365/392: https://docs.aws.amazon.com/vpc/latest/reachability/explanation-codes.html
# Processed 366/392: https://docs.aws.amazon.com/vpc/latest/reachability/additional-detail-codes.html
# Processed 367/392: https://docs.aws.amazon.com/vpc/latest/reachability/multi-account.html
# Processed 368/392: https://docs.aws.amazon.com/vpc/latest/reachability/identity-access-management.html
# Processed 369/392: https://docs.aws.amazon.com/vpc/latest/reachability/security_iam_service-with-iam.html
# Processed 370/392: https://docs.aws.amazon.com/vpc/latest/reachability/using-service-linked-roles.html
# Processed 371/392: https://docs.aws.amazon.com/vpc/latest/reachability/security-iam-awsmanpol.html
# Processed 372/392: https://docs.aws.amazon.com/vpc/latest/reachability/cross-account-access-roles.html
# Processed 373/392: https://docs.aws.amazon.com/vpc/latest/reachability/reachability-analyzer-limits.html
# Processed 374/392: https://docs.aws.amazon.com/vpc/latest/reachability/doc-history.html
# Processed 375/392: https://docs.aws.amazon.com/network-manager/latest/infrastructure-performance/what-is-nmip.html
# Processed 376/392: https://docs.aws.amazon.com/network-manager/latest/infrastructure-performance/how-nmip-works.html
# Processed 377/392: https://docs.aws.amazon.com/network-manager/latest/infrastructure-performance/getting-started-nmip-console.html
# Processed 378/392: https://docs.aws.amazon.com/network-manager/latest/infrastructure-performance/nmip-subscriptions-cw.html
# Processed 379/392: https://docs.aws.amazon.com/network-manager/latest/infrastructure-performance/identity-access-management.html
# Processed 380/392: https://docs.aws.amazon.com/network-manager/latest/infrastructure-performance/security_iam_service-with-iam.html
# Processed 381/392: https://docs.aws.amazon.com/network-manager/latest/infrastructure-performance/security_iam_create-iam-policy.html
# Processed 382/392: https://docs.aws.amazon.com/network-manager/latest/infrastructure-performance/doc-history.html
# Processed 383/392: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/what-is-network-access-analyzer.html
# Processed 384/392: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/how-network-access-analyzer-works.html
# Processed 385/392: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/getting-started.html
# Processed 386/392: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/getting-started-cli.html
# Processed 387/392: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/working-with-network-access-scopes.html
# Processed 388/392: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/identity-access-management.html
# Processed 389/392: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/security_iam_service-with-iam.html
# Processed 390/392: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/security-iam-awsmanpol.html
# Processed 391/392: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/network-access-analyzer-limits.html
# Processed 392/392: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/doc-history.html

# %%
import openai

def create_qa_prompt(content):
    # Create a prompt asking the model to generate a question and answer based on the content
    instructions = f"""
    Based on ONLY the contents below, please generate as many HIGH-QUALITY question answer pairs as there is information for. I want ONLY one of two responses below. Please make the question ONE SENTENCE and the answer ONE PARAGRAPH. I want you to focus on the MAIN IDEA of the articles for the questions. 

    FIRST CASE: If you determine that there IS enough information to produce a HIGH-QUALITY question answer pair, please return the answer in EXACTLY the format here:

    QUESTION: ...

    ANSWER: ...

    SECOND CASE: If you determine that there IS NOT enough information to produce a HIGH-QUALITY question answer pair, please return 'NOT ENOUGH INFORMATION'

    Here is the content of the webpage: {content}
    """
    return instructions

def get_openai_qa_response(prompt):
    try:
        response = openai.ChatCompletion.create(
            model="gpt-4-1106-preview",
            messages=[{"role": "system", "content": "Do EXACTLY as the instructions in the prompt say."},
                      {"role": "user", "content": prompt}]
        )
        return response['choices'][0]['message']['content']
    except Exception as e:
        print(f"Error in getting response: {e}")
        return None

# Load API key from .env file
load_dotenv()
openai_api_key_env_var = "OPENAI_KEY"
openai.api_key = os.getenv(openai_api_key_env_var)

output_file = "output_doc_qa_pairs.txt"  # Name of the file where you want to save the output

# Assuming 'processed_contents' is a dictionary where keys are URLs and values are the content of those URLs
for url, content in processed_contents.items():
    prompt = create_qa_prompt(content)  # Create a prompt for generating Q&A
    qa_response = get_openai_qa_response(prompt)  # Get the Q&A response from OpenAI

    # Open the file in append mode and write the URL and Q&A
    with open(output_file, "a") as file:
        file.write(f"URL: {url}\nQ&A:\n{qa_response}\n\n")

    print(f"Processed URL: {url}")

print(f"Output saved to {output_file}")
# Out:
# Processed URL: https://docs.aws.amazon.com/cli/latest/reference/vpc-lattice/
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/how-it-works.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-getting-started.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-ip-addressing.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-cidr-blocks.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/subnet-sizing.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/managed-prefix-lists.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/working-with-managed-prefix-lists.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/working-with-aws-managed-prefix-lists.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/sharing-managed-prefix-lists.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/managed-prefix-lists-referencing.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/aws-ip-ranges.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-migrate-ipv6.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/aws-ipv6-support.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/configure-your-vpc.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/default-vpc.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/create-vpc.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/modify-vpcs.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/VPC_DHCP_Options.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/DHCPOptionSetConcepts.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/DHCPOptionSet.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-dns.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/network-address-usage.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-sharing.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/example-vpc-share.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/Extend_VPCs.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/delete-vpc.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/configure-subnets.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/create-subnets.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/modify-subnets.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/subnet-cidr-reservation.html
# Error in getting response: Request timed out: HTTPSConnectionPool(host='api.openai.com', port=443): Read timed out. (read timeout=600)
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/VPC_Route_Tables.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/route-table-options.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/WorkWithRouteTables.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/middlebox-routing-console.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/working-with-routing-console.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/middlebox-routing-examples.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/internet-gateway-subnet.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/gwlb-route.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/intra-vpc-route.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/subnet-deleting.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/extend-intro.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/VPC_Internet_Gateway.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/egress-only-internet-gateway.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-nat.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-nat-gateway.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/nat-gateway-scenarios.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/nat-gateway-nat64-dns64.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-nat-gateway-cloudwatch.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/nat-gateway-troubleshooting.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/VPC_NAT_Instance.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-eips.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/extend-tgw.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpn-connections.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-peering.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/monitoring.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/flow-logs.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/flow-logs-records-examples.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/working-with-flow-logs.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/flow-logs-cwl.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/flow-logs-s3.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/flow-logs-firehose.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/flow-logs-athena.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/flow-logs-troubleshooting.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-cloudwatch.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/security.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/data-protection.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/VPC_Security.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/security-iam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/security_iam_service-with-iam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-policy-examples.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/security_iam_troubleshoot.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/security-iam-awsmanpol.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/infrastructure-security.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-security-groups.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/security-groups.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/security-group-rules.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/default-security-group.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-network-acls.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/disaster-recovery-resiliency.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/VPC-compliance.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-security-best-practices.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/related-services.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/endpoint-services-overview.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/network-firewall.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/resolver-dns-firewall.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-examples-intro.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-example-dev-test.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-example-web-database-servers.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/vpc-example-private-subnets-nat.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/amazon-vpc-limits.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/userguide/WhatsNew.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/what-is-vpc-peering.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/vpc-peering-basics.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/working-with-vpc-peering.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/create-vpc-peering-connection.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/accept-vpc-peering-connection.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/reject-vpc-peering-connection.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/describe-vpc-peering-connections.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/vpc-peering-routing.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/vpc-peering-security-groups.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/modify-peering-connections.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/delete-vpc-peering-connection.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/troubleshoot-vpc-peering-connections.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/peering-configurations.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/peering-configurations-full-access.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/peering-configurations-partial-access.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/peering-scenarios.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/security-iam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/vpc-peering-connection-quotas.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/peering/doc-history.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/what-is-traffic-mirroring.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-how-it-works.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-targets.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-sessions.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-connection.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-packet-formats.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-getting-started.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/Traffic_Mirroring_Scenarios.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/tm-example-inbound-tcp.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/tm-example-inbound-tcp-udp.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/tm-example-non-vpc.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/tm-example-glb-endpoints.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/working-with-traffic-mirroring.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-target.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/cross-account-traffic-mirroring-targets.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-filter.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-session.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/tm-example-open-source.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirror-cloudwatch.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-limits.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/traffic-mirroring-security.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/mirroring/doc-history.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/what-is-privatelink.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/concepts.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/getting-started.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/privatelink-access-aws-services.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/aws-services-privatelink-support.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/create-interface-endpoint.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/interface-endpoints.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/manage-notifications-endpoint.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/delete-interface-endpoint.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/gateway-endpoints.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/vpc-endpoints-s3.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/vpc-endpoints-ddb.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/privatelink-access-saas.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/vpce-gateway-load-balancer.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/create-gateway-load-balancer-endpoint-service.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/gateway-load-balancer-endpoints.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/privatelink-share-your-services.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/create-endpoint-service.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/configure-endpoint-service.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/manage-dns-names.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/create-notification-endpoint-service.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/delete-endpoint-service.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/vpc-endpoints-iam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/security_iam_service-with-iam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/security_iam_id-based-policy-examples.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/vpc-endpoints-access.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/privatelink-cloudwatch-metrics.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/vpc-limits-endpoints.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/privatelink/doc-history.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/what-is-transit-gateway.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/how-transit-gateways-work.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-getting-started.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-best-design-practices.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/TGW_Scenarios.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-centralized-router.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-isolated.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-isolated-shared.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-peering-scenario.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-nat-igw.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-appliance-scenario.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/working-with-transit-gateways.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-transit-gateways.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-vpc-attachments.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-vpn-attachments.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-dcg-attachments.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-peering.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-connect.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-route-tables.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-prefix-lists.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-policy-tables.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-multicast-overview.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/how-multicast-works.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/working-with-multicast.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/manage-domain.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/manage-multicast-group.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/multicast-sharing.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-share.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-flow-logs.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/flow-logs-cwl.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/flow-logs-s3.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/flow-logs-kinesis.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/working-with-flow-logs.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-monitoring.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-cloudwatch-metrics.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-cloudtrail-logs.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-authentication-access-control.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/service-linked-roles.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/security-iam-awsmanpol.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/tgw-nacls.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/transit-gateway-quotas.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/tgw/doc-history.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/what-it-is-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/how-it-works-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/access-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/choose-single-user-or-orgs-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/enable-integ-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/enable-integ-ipam-outside-org.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/enable-integ-ipam-outside-org-considerations.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/enable-integ-ipam-outside-org-process.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/enable-single-user-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/create-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/planning-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/planning-examples-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/intro-create-ipv4-pools.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/create-top-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/create-reg-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/create-dev-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/intro-create-ipv6-pools.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/create-ipv6-reg-pool.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/create-ipv6-dev-pool.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/allocate-cidrs-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/create-vpc-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/manually-allocate-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/managing-ip-space-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/scp-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/share-pool-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/prov-cidr-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/depro-pool-cidr-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/mod-pool-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/delete-pool-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/res-disc-work-with.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/res-disc-work-with-create.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/res-disc-work-with-view.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/res-disc-work-with-share.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/res-disc-work-with-associate.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/res-disc-work-with-disassociate.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/res-disc-work-with-delete.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/add-scope-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/move-resource-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/change-monitoring-state-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/delete-scope-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/release-alloc-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/delete-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/tracking-ip-addresses-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/monitor-cidr-usage-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/monitor-cidr-compliance-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/cloudwatch-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/cloudwatch-ipam-ip-address-usage.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/cloudwatch-ipam-res-util.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/view-history-cidr-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/view-public-ip-insights.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-get-started-console.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-create-vpc-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-historical-insights.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-byoip-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-byoip-ipam-console-intro.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-byoip-ipam-console-ipv4.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-byoip-ipam-console-ipv6.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-byoip-ipam-cli-only-intro.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-byoip-ipam-ipv4.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-byoip-ipam-ipv6.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/tutorials-byoip-ipam-transfer-ipv4.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/iam-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/iam-ipam-slr.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/iam-ipam-managed-pol.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/iam-ipam-policy-examples.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/quotas-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/pricing-ipam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/related-info.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/ipam/doc-history-ipam.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/what-are-global-networks.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/how-gnw-works.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/gnw-getting-started.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/gnw-scenarios.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/working-with-gnws.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-multi-account.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-multi-account-troubleshooting.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/global-networks.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/tgw-registrations.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/sites.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/links.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/devices.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/device-connections.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/cgw-association.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/connect-peer-association.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/tgw-visualize-networks.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-monitoring-console.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-visualize-tgw.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/monitoring-overview.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/monitoring-cloudwatch-metrics.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/cw-metrics-on-premises.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/viewing-metrics.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/monitoring-events.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/route-analyzer.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/tgw-nm-multi.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-security-iam.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-service-linked-roles.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/security-iam-awsmanpol.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-custom-multi-role.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/gnw-tagging.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-logging-using-cloudtrail.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/nm-quotas.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/tgwnm/doc-history.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/what-is-cloudwan.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-getting-started.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/create-global-network.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-core-network-policy.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-create-attachment.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-connect-attachment.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-connect-peer-attachment.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-tgw-attachment.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-vpc-attachment.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-vpn-attachment.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-register-tgw.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-sites.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-devices.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-working-with.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-networks-working-with.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-create-policy-version.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-core-network-config.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-segments.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-network-actions-routes.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-attachments.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-change-sets.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policies-json.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-examples.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-examples-one-segment-region.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-examples-two-segments-regions.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-examples-edge-consolidation.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-examples-three-stage.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-examples-distributed-wan.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-policy-examples-firewalls.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-attachments-working-with.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-peerings.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-share-network.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-shared.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-attachments-share.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-peerings-share.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-tags.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-sites-working-with.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-devices-working.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-visualize-networks.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-visualize-networks-global.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-visualize-networks-core.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-visualize-tgw.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-tgw-networks.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-tgws-working-with.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-security.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/security-iam-awsmanpol.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cwan-using-service-linked-roles.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-events-metrics.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-onboard-events.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-cloudwatch-events.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-cloudwatch-metrics.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/cloudwan-quotas.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/cloudwan/doc-history.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/reachability/what-is-reachability-analyzer.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/reachability/how-reachability-analyzer-works.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/reachability/getting-started.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/reachability/getting-started-cli.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/reachability/explanation-codes.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/reachability/additional-detail-codes.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/reachability/multi-account.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/reachability/identity-access-management.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/reachability/security_iam_service-with-iam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/reachability/using-service-linked-roles.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/reachability/security-iam-awsmanpol.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/reachability/cross-account-access-roles.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/reachability/reachability-analyzer-limits.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/reachability/doc-history.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/infrastructure-performance/what-is-nmip.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/infrastructure-performance/how-nmip-works.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/infrastructure-performance/getting-started-nmip-console.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/infrastructure-performance/nmip-subscriptions-cw.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/infrastructure-performance/identity-access-management.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/infrastructure-performance/security_iam_service-with-iam.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/infrastructure-performance/security_iam_create-iam-policy.html
# Processed URL: https://docs.aws.amazon.com/network-manager/latest/infrastructure-performance/doc-history.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/what-is-network-access-analyzer.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/how-network-access-analyzer-works.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/getting-started.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/getting-started-cli.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/working-with-network-access-scopes.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/identity-access-management.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/security_iam_service-with-iam.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/security-iam-awsmanpol.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/network-access-analyzer-limits.html
# Processed URL: https://docs.aws.amazon.com/vpc/latest/network-access-analyzer/doc-history.html
# Output saved to output_doc_qa_pairs.txt
